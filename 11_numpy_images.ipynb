# %%
# pip install Pillow
from PIL import Image
import numpy as np

image = Image.open("/Users/cesar/Downloads/FIRMA.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x2000>

# %%
image_arr = np.array(image)
image_arr
# Out:
# array([[[179, 180, 164],
#         [179, 180, 164],
#         [179, 180, 164],
#         ...,
#         [194, 195, 177],
#         [194, 195, 177],
#         [194, 195, 177]],
#
#        [[179, 180, 164],
#         [179, 180, 164],
#         [179, 180, 164],
#         ...,
#         [195, 196, 178],
#         [195, 196, 178],
#         [195, 196, 178]],
#
#        [[179, 180, 164],
#         [179, 180, 164],
#         [179, 180, 164],
#         ...,
#         [195, 196, 178],
#         [195, 196, 178],
#         [195, 196, 178]],
#
#        ...,
#
#        [[161, 165, 166],
#         [161, 165, 166],
#         [161, 165, 166],
#         ...,
#         [197, 199, 196],
#         [197, 199, 196],
#         [197, 199, 196]],
#
#        [[160, 164, 165],
#         [161, 165, 166],
#         [161, 165, 166],
#         ...,
#         [197, 199, 196],
#         [197, 199, 196],
#         [197, 199, 196]],
#
#        [[159, 163, 164],
#         [160, 164, 165],
#         [160, 164, 165],
# ...

# %%
image_arr.shape
# Out:
# (2000, 1500, 3)

# %%
image_arr.max()
# Out:
# 212

# %%
image_arr[:,:,:] = 255

# %%
image_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
Image.fromarray(image_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x2000>
